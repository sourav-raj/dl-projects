# %%
# -*- coding: utf-8 -*-
# Indentation: Jupyter Notebook

'''
ANN for Churn Prediction
'''

__version__ = 1.0
__author__ = "Sourav Raj"
__author_email__ = "souravraj.iitbbs@gmail.com"

# %%
import tensorflow as tf

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('../data/Churn_Modelling.csv')

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
X=data.iloc[:,3:13].values
y=data.iloc[:,13].values

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_1 = LabelEncoder()
X[:, 1]= labelencoder_X_1.fit_transform(X[:,1])
labelencoder_X_2 = LabelEncoder()
X[:, 2]= labelencoder_X_2.fit_transform(X[:,2])
onehotencoder = OneHotEncoder(categorical_features = [1])
X = onehotencoder.fit_transform(X).toarray()

# %%
X=X[:, 1:]

# %%
X
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   6.19000000e+02, ...,
#           1.00000000e+00,   1.00000000e+00,   1.01348880e+05],
#        [  0.00000000e+00,   1.00000000e+00,   6.08000000e+02, ...,
#           0.00000000e+00,   1.00000000e+00,   1.12542580e+05],
#        [  0.00000000e+00,   0.00000000e+00,   5.02000000e+02, ...,
#           1.00000000e+00,   0.00000000e+00,   1.13931570e+05],
#        ...,
#        [  0.00000000e+00,   0.00000000e+00,   7.09000000e+02, ...,
#           0.00000000e+00,   1.00000000e+00,   4.20855800e+04],
#        [  1.00000000e+00,   0.00000000e+00,   7.72000000e+02, ...,
#           1.00000000e+00,   0.00000000e+00,   9.28885200e+04],
#        [  0.00000000e+00,   0.00000000e+00,   7.92000000e+02, ...,
#           1.00000000e+00,   0.00000000e+00,   3.81907800e+04]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# ANN
import keras 
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
# initializing the ANN
classifier = Sequential()

# %%
# adding the input layer & first hidden layer
classifier.add(Dense(output_dim=6, init= 'uniform', activation = 'relu', input_dim = 11))
# Out:
# C:\Users\sourav.raj.IN\AppData\Local\conda\conda\envs\python36\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=11, units=6, kernel_initializer="uniform")`

# %%
# adding the 2nd hidden layer
classifier.add(Dense(output_dim=6, init= 'uniform', activation = 'relu'))
# Out:
# C:\Users\sourav.raj.IN\AppData\Local\conda\conda\envs\python36\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=6, kernel_initializer="uniform")`

# %%
# adding the output layer
classifier.add(Dense(output_dim=1, init= 'uniform', activation = 'sigmoid'))
# Out:
# C:\Users\sourav.raj.IN\AppData\Local\conda\conda\envs\python36\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1, kernel_initializer="uniform")`

# %%
# compiling the ANN
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics =['accuracy'])

# %%
# fitting the ANN to training set
classifier.fit(X_train, y_train, batch_size=10, nb_epoch=100 )
# Out:
# C:\Users\sourav.raj.IN\AppData\Local\conda\conda\envs\python36\lib\site-packages\keras\models.py:942: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/100
# 8000/8000 [==============================] - 4s 469us/step - loss: 0.4885 - acc: 0.7955
# Epoch 2/100
# 8000/8000 [==============================] - 1s 148us/step - loss: 0.4301 - acc: 0.7960
# Epoch 3/100
# 8000/8000 [==============================] - 1s 153us/step - loss: 0.4255 - acc: 0.7960
# Epoch 4/100
# 8000/8000 [==============================] - 1s 154us/step - loss: 0.4216 - acc: 0.8076
# Epoch 5/100
# 8000/8000 [==============================] - 1s 147us/step - loss: 0.4187 - acc: 0.8205
# Epoch 6/100
# 8000/8000 [==============================] - 1s 160us/step - loss: 0.4170 - acc: 0.8261
# Epoch 7/100
# 8000/8000 [==============================] - 1s 150us/step - loss: 0.4150 - acc: 0.8280
# Epoch 8/100
# 8000/8000 [==============================] - 1s 147us/step - loss: 0.4134 - acc: 0.8295
# Epoch 9/100
# 8000/8000 [==============================] - 1s 166us/step - loss: 0.4125 - acc: 0.8331
# Epoch 10/100
# 8000/8000 [==============================] - 1s 150us/step - loss: 0.4113 - acc: 0.8335
# Epoch 11/100
# 8000/8000 [==============================] - 1s 159us/step - loss: 0.4103 - acc: 0.8327
# Epoch 12/100
# 8000/8000 [==============================] - 1s 148us/step - loss: 0.4093 - acc: 0.8332
# Epoch 13/100
# 8000/8000 [==============================] - 1s 150us/step - loss: 0.4087 - acc: 0.8345
# Epoch 14/100
# 8000/8000 [==============================] - 1s 157us/step - loss: 0.4077 - acc: 0.8354
# Epoch 15/100
# 8000/8000 [==============================] - 1s 151us/step - loss: 0.4073 - acc: 0.8350
# Epoch 16/100
# 8000/8000 [==============================] - 1s 154us/step - loss: 0.4066 - acc: 0.8351
# Epoch 17/100
# 8000/8000 [==============================] - 1s 138us/step - loss: 0.4065 - acc: 0.8337
# Epoch 18/100
# 8000/8000 [==============================] - 1s 153us/step - loss: 0.4058 - acc: 0.8347
# Epoch 19/100
# 8000/8000 [==============================] - 1s 140us/step - loss: 0.4053 - acc: 0.8336
# Epoch 20/100
# 8000/8000 [==============================] - 1s 139us/step - loss: 0.4045 - acc: 0.8364
# Epoch 21/100
# 8000/8000 [==============================] - 1s 152us/step - loss: 0.4047 - acc: 0.8339
# Epoch 22/100
# 8000/8000 [==============================] - 1s 156us/step - loss: 0.
# 8000/8000 [==============================] - 2s 221us/step - loss: 0.4000 - acc: 0.8361
# Epoch 75/100
# 8000/8000 [==============================] - 2s 256us/step - loss: 0.4001 - acc: 0.8354
# Epoch 76/100
# 8000/8000 [==============================] - 2s 266us/step - loss: 0.4003 - acc: 0.8372
# Epoch 77/100
# 8000/8000 [==============================] - 2s 254us/step - loss: 0.3996 - acc: 0.8352
# Epoch 78/100
# 8000/8000 [==============================] - 2s 222us/step - loss: 0.4004 - acc: 0.8356
# Epoch 79/100
#  - ETA: 1s - loss: 0.4033 - acc: 0.8354
# Epoch 80/100
#  - ETA: 0s - loss: 0.4025 - acc: 0.8332
# Epoch 81/100
#  - ETA: 0s - loss: 0.3903 - acc: 0.8411
# Epoch 82/100
# 8000/8000 [==============================] - 2s 253us/step - loss: 0.3997 - acc: 0.8349
# Epoch 83/100
# 8000/8000 [==============================] - 3s 318us/step - loss: 0.3996 - acc: 0.8345
# Epoch 84/100
# 8000/8000 [==============================] - 2s 227us/step - loss: 0.3998 - acc: 0.8351
# Epoch 85/100
# 8000/8000 [==============================] - 2s 254us/step - loss: 0.3993 - acc: 0.8339
# Epoch 86/100
#  - ETA: 0s - loss: 0.4020 - acc: 0.8353
# Epoch 87/100
# 8000/8000 [==============================] - 2s 254us/step - loss: 0.3998 - acc: 0.8357
# Epoch 88/100
#  - ETA: 0s - loss: 0.4020 - acc: 0.8360
# Epoch 89/100
# 8000/8000 [==============================] - 2s 269us/step - loss: 0.3996 - acc: 0.8347
# Epoch 90/100
#  - ETA: 0s - loss: 0.4061 - acc: 0.8303
# Epoch 91/100
# 8000/8000 [==============================] - 2s 256us/step - loss: 0.4001 - acc: 0.8364
# Epoch 92/100
# 8000/8000 [==============================] - 2s 223us/step - loss: 0.4001 - acc: 0.8360
# Epoch 93/100
#  - ETA: 1s - loss: 0.3880 - acc: 0.8466
# Epoch 94/100
# 8000/8000 [==============================] - 2s 242us/step - loss: 0.3995 - acc: 0.8354
# Epoch 95/100
#  - ETA: 0s - loss: 0.4027 - acc: 0.8347
# Epoch 96/100
# 8000/8000 [==============================] - 2s 211us/step - loss: 0.4001 - acc: 0.8342
# Epoch 97/100
# 8000/8000 [==============================] - 2s 229us/step - loss: 0.4000 - acc: 0.8346
# Epoch 98/100
# 8000/8000 [==============================] - 2s 211us/step - loss: 0.3997 - acc: 0.8346
# Epoch 99/100
# 8000/8000 [==============================] - 2s 235us/step - loss: 0.3997 - acc: 0.8341
# Epoch 100/100
# 8000/8000 [==============================] - 2s 199us/step - loss: 0.4000 - acc: 0.8362

# %%
y_pred = classifier.predict(X_test)

# %%
y_pred[1:10]
# Out:
# array([[ 0.33631179],
#        [ 0.18487103],
#        [ 0.06216956],
#        [ 0.16657516],
#        [ 0.85727119],
#        [ 0.06694856],
#        [ 0.07193249],
#        [ 0.1100153 ],
#        [ 0.87042791]], dtype=float32)

# %%
y_pred = (y_pred > 0.50)
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]], dtype=bool)

# %%
new_prediction = classifier.predict(sc.transform(np.array([[0,0, 600, 1, 40, 3, 6000,2, 1,1, 50000]])))

# %%
new_prediction = (new_prediction > 0.50)
new_prediction

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[1543,   52],
#        [ 266,  139]], dtype=int64)

# %%
(1549 +133 )/2000
# Out:
# 0.841
